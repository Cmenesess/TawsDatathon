# %%
import pandas as pd

# %%
df = pd.read_csv("../data/teletrabajo_ec.csv")
df
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8360\3797412445.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/teletrabajo_ec.csv")
#       motivo_teletrabajo     genero         provincia_contrato  \
# 0              Emergente   Femenino                  PICHINCHA
# 1              Emergente   Femenino                  PICHINCHA
# 2              Emergente   Femenino                  PICHINCHA
# 3              Emergente   Femenino                     GUAYAS
# 4              Emergente   Femenino                  PICHINCHA
# ...                  ...        ...                        ...
# 40661           Habitual  Masculino                  PICHINCHA
# 40662           Habitual  Masculino                  PICHINCHA
# 40663           Habitual  Masculino  CHIMBORAZO(REGIMEN COSTA)
# 40664           Habitual  Masculino                  PICHINCHA
# ...

# %%
df_time = df.set_index("anio_fecha_inicio_teletrabajo", drop=True, append=False, inplace=False, verify_integrity=False)
df_time
# Out:
#                               motivo_teletrabajo     genero  \
# anio_fecha_inicio_teletrabajo
# 2017                                   Emergente   Femenino
# 2018                                   Emergente   Femenino
# 2018                                   Emergente   Femenino
# 2019                                   Emergente   Femenino
# 2019                                   Emergente   Femenino
# ...                                          ...        ...
# 2022                                    Habitual  Masculino
# 2022                                    Habitual  Masculino
# 2022                                    Habitual  Masculino
# 2022                                    Habitual  Masculino
# 2022                                    Habitual  Masculino
#
#                                       provincia_contrato  \
# anio_fecha_inicio_teletrabajo
# 2017                                           PICHINCHA
# 2018                                           PICHINCHA
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sbn
sbn.set(rc={'figure.figsize':(10, 5)})

# %%
plt.figure(figsize = (15,8))
p = sbn.lineplot(x = 'anio_fecha_inicio_teletrabajo', y = 'contratos',data = df)
p.set_xlabel("Año de inicio de teletrabajo", fontsize = 15)
p.set_ylabel("Contratos", fontsize = 15)
# Out:
# Text(0, 0.5, 'Contratos')
