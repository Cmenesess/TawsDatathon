# %%
import pandas as pd

# %%
df1 = pd.read_csv("../data/teletrabajo_2022septiembre_limpia.csv")
df1
# Out:
#       motivo_teletrabajo     genero         provincia_contrato  \
# 0              Emergente   Femenino                  PICHINCHA
# 1              Emergente   Femenino                  PICHINCHA
# 2              Emergente   Femenino                  PICHINCHA
# 3              Emergente   Femenino                     GUAYAS
# 4              Emergente   Femenino                  PICHINCHA
# ...                  ...        ...                        ...
# 40661           Habitual  Masculino                  PICHINCHA
# 40662           Habitual  Masculino                  PICHINCHA
# 40663           Habitual  Masculino  CHIMBORAZO(REGIMEN COSTA)
# 40664           Habitual  Masculino                  PICHINCHA
# 40665           Habitual  Masculino                  PICHINCHA
#
#       provincia_contrato (grupo)  finalizado  contratos  \
# 0                      PICHINCHA     Vigente          1
# 1                      PICHINCHA     Vigente          1
# ...

# %%
df2 = pd.read_csv("../data/ruc_info_cleaning.csv")
df2
# Out:
#            numeroRuc                                        razonSocial  \
# 0      1791256115001                                        OTECEL S.A.
# 1      1792381053001                                  IPEGES CIA. LTDA.
# 2       791755093001                                         MEGANET SA
# 3      1792692091001  INMOBILIARIA TESLA BUILDINGS CORPORATION 'GEST...
# 4      1790049795001                             MODERNA ALIMENTOS S.A.
# ...              ...                                                ...
# 13048  1391924127001                                    VITALMEDIC S.A.
# 13049   992169362001                                        GUALIN S.A.
# 13050  1792832411001                                      PRACHTIG C.A.
# 13051  1792701287001              AGUINARVING INGENIERIA & AGUILAR S.A.
# 13052  1791897315001  CORPORACION LIDERES PARA FORMACION Y CAPACITAC...
#
#       estadoPersonaNatural estadoSociedad claseContribuyente obligado  \
# ...

# %%
df2['numeroRuc'] = df2['numeroRuc'].apply(str)
df2.dtypes
# Out:
# numeroRuc                  object
# razonSocial                object
# estadoPersonaNatural       object
# estadoSociedad             object
# claseContribuyente         object
# obligado                   object
# actividadContribuyente     object
# representanteLegal         object
# agenteRepresentante        object
# personaSociedad            object
# subtipoContribuyente       object
# motivoCancelacion         float64
# motivoSuspension          float64
# fechaInicioActividad       object
# fechaCese                  object
# fechaInscripcion           object
# fechaActualizacion         object
# dtype: object

# %%
df = df1.merge(df2, how='left', left_on="ruc_empresa", right_on="numeroRuc")
df
# Out:
#       motivo_teletrabajo     genero         provincia_contrato  \
# 0              Emergente   Femenino                  PICHINCHA
# 1              Emergente   Femenino                  PICHINCHA
# 2              Emergente   Femenino                  PICHINCHA
# 3              Emergente   Femenino                     GUAYAS
# 4              Emergente   Femenino                  PICHINCHA
# ...                  ...        ...                        ...
# 40661           Habitual  Masculino                  PICHINCHA
# 40662           Habitual  Masculino                  PICHINCHA
# 40663           Habitual  Masculino  CHIMBORAZO(REGIMEN COSTA)
# 40664           Habitual  Masculino                  PICHINCHA
# 40665           Habitual  Masculino                  PICHINCHA
#
#       provincia_contrato (grupo)  finalizado  contratos  \
# 0                      PICHINCHA     Vigente          1
# 1                      PICHINCHA     Vigente          1
# ...

# %%
df.dtypes
# Out:
# motivo_teletrabajo                        object
# genero                                    object
# provincia_contrato                        object
# provincia_contrato (grupo)                object
# finalizado                                object
# contratos                                  int64
# anio_fecha_inicio_teletrabajo              int64
# anio_fecha_inicio_teletrabajo (grupo)     object
# canton_contrato                           object
# estado_teletrabajo                        object
# fecha_consulta                            object
# mes_fecha_inicio_teletrabajo              object
# modo_ejecucion                            object
# Número de registros                        int64
# ruc_empresa                               object
# numeroRuc                                 object
# razonSocial                               object
# estadoPersonaNatural                      object
# estadoSociedad                            object
# ...

# %%
df3 = pd.read_csv("../data/super_cias_filtered.csv")
df3
# Out:
#       No. FILA  EXPEDIENTE            RUC  \
# 0            2           2  1790004724001
# 1           11          63  1790084604001
# 2           15          78  1790027740001
# 3           17          83  1890000130001
# 4           18          85  1790014797001
# ...        ...         ...            ...
# 7424    174275      743701   993371717001
# 7425    174318      743744   993372003001
# 7426    174382      743808  1793195901001
# 7427    175450      744876  1793197141001
# 7428    175903      745331  1793198363001
#
#                                              NOMBRE SITUACIÓN LEGAL  \
# 0                     ACERIA DEL ECUADOR CA ADELCA.          ACTIVA
# 1                                    CONFITECA C.A.          ACTIVA
# 2                                    ASTAP CIA LTDA          ACTIVA
# 3                ASSA-AUTOMOTORES DE LA SIERRA S.A.          ACTIVA
# 4            AUTOMOTORES Y ANEXOS S.A. (A.Y.A.S.A.)          ACTIVA
# ...

# %%
df3 = df3.rename(index=str, columns={"PAÍS": "PAÍS_CIA", "REGIÓN": "REGIÓN_CIA", "CANTÓN": "CANTÓN_CIA", "CIUDAD":"CIUDAD_NEW"})

# %%
df3.drop(['No. FILA'], axis=1, inplace=True)

# %%
df3.dtypes
# Out:
# EXPEDIENTE             int64
# RUC                    int64
# NOMBRE                object
# SITUACIÓN LEGAL       object
# FECHA_CONSTITUCION    object
# TIPO                  object
# PAÍS_CIA              object
# REGIÓN_CIA            object
# PROVINCIA             object
# CANTÓN_CIA            object
# CIUDAD_NEW            object
# REPRESENTANTE         object
# CAPITAL SUSCRITO      object
# dtype: object

# %%
df3['RUC'] = df3['RUC'].apply(str)

# %%
df = df.merge(df3, how='left', left_on="ruc_empresa", right_on="RUC")
df
# Out:
#       motivo_teletrabajo     genero         provincia_contrato  \
# 0              Emergente   Femenino                  PICHINCHA
# 1              Emergente   Femenino                  PICHINCHA
# 2              Emergente   Femenino                  PICHINCHA
# 3              Emergente   Femenino                     GUAYAS
# 4              Emergente   Femenino                  PICHINCHA
# ...                  ...        ...                        ...
# 40661           Habitual  Masculino                  PICHINCHA
# 40662           Habitual  Masculino                  PICHINCHA
# 40663           Habitual  Masculino  CHIMBORAZO(REGIMEN COSTA)
# 40664           Habitual  Masculino                  PICHINCHA
# 40665           Habitual  Masculino                  PICHINCHA
#
#       provincia_contrato (grupo)  finalizado  contratos  \
# 0                      PICHINCHA     Vigente          1
# 1                      PICHINCHA     Vigente          1
# ...

# %%
df[["ruc_empresa", "numeroRuc", "RUC"]]
# Out:
#          ruc_empresa      numeroRuc            RUC
# 0      1792040825001  1792040825001  1792040825001
# 1      1792692091001  1792692091001  1792692091001
# 2      1791109384001  1791109384001            NaN
# 3      1791256115001  1791256115001  1791256115001
# 4      1791256115001  1791256115001  1791256115001
# ...              ...            ...            ...
# 40661  1792356601001  1792356601001  1792356601001
# 40662  1792964547001  1792964547001  1792964547001
# 40663  0603728668001            NaN            NaN
# 40664  1791256115001  1791256115001  1791256115001
# 40665  1791753283001  1791753283001  1791753283001
#
# [40666 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# motivo_teletrabajo                           0
# genero                                       0
# provincia_contrato                           0
# provincia_contrato (grupo)                   0
# finalizado                                   0
# contratos                                    0
# anio_fecha_inicio_teletrabajo                0
# anio_fecha_inicio_teletrabajo (grupo)        0
# canton_contrato                              0
# estado_teletrabajo                           0
# fecha_consulta                               0
# mes_fecha_inicio_teletrabajo                 0
# modo_ejecucion                               0
# Número de registros                          0
# ruc_empresa                                  0
# numeroRuc                                13750
# razonSocial                              13750
# estadoPersonaNatural                     38799
# estadoSociedad                           15617
# claseContribuyente                       13750
# ...

# %%
df.drop(['numeroRuc', 'RUC'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# motivo_teletrabajo                           0
# genero                                       0
# provincia_contrato                           0
# provincia_contrato (grupo)                   0
# finalizado                                   0
# contratos                                    0
# anio_fecha_inicio_teletrabajo                0
# anio_fecha_inicio_teletrabajo (grupo)        0
# canton_contrato                              0
# estado_teletrabajo                           0
# fecha_consulta                               0
# mes_fecha_inicio_teletrabajo                 0
# modo_ejecucion                               0
# Número de registros                          0
# ruc_empresa                                  0
# razonSocial                              13750
# estadoPersonaNatural                     38799
# estadoSociedad                           15617
# claseContribuyente                       13750
# obligado                                 13750
# ...

# %%
df.iloc[:,:].to_csv("../data/teletrabajo_ec.csv",index=False)
